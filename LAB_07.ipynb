# %% [markdown]
# <a href="https://colab.research.google.com/github/havanluan/CS114.K21/blob/master/LAB_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bài toán dự đoán giá nhà dựa trên tập dữ liệu

# %% [markdown]
# ## Cài đặt turicreate

# %%
pip install -U turicreate

# %% [markdown]
# ## Kết nối dữ liệu

# %%
import turicreate

# %% [markdown]
# // *Sau khi tải lên file .zip thì giải nén bằng lệnh pip*

# %%
# !unzip \*.zip
# Out:
# Archive:  2SnLy-JAEemx8A5HK6Ls8g_0ccbc21b1656423ba7e9d7fe2971879a_home_data.sframe.zip
#   inflating: home_data.sframe/m_1ce96d9d245ca490.0000
#    creating: __MACOSX/
#    creating: __MACOSX/home_data.sframe/
#   inflating: __MACOSX/home_data.sframe/._m_1ce96d9d245ca490.0000
#   inflating: home_data.sframe/dir_archive.ini
#   inflating: __MACOSX/home_data.sframe/._dir_archive.ini
#   inflating: home_data.sframe/m_1ce96d9d245ca490.frame_idx
#   inflating: __MACOSX/home_data.sframe/._m_1ce96d9d245ca490.frame_idx
#  extracting: home_data.sframe/objects.bin
#   inflating: __MACOSX/home_data.sframe/._objects.bin
#   inflating: home_data.sframe/m_1ce96d9d245ca490.sidx
#   inflating: __MACOSX/home_data.sframe/._m_1ce96d9d245ca490.sidx
#   inflating: __MACOSX/._home_data.sframe

# %% [markdown]
# *// Đọc file SFrame sau khi giải nén*

# %%
sales = turicreate.SFrame('/content/home_data.sframe')

# %%
sales
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000.0 |   4.0    |    3.0    |
# ...

# %% [markdown]
# ## Trực quan hóa dữ liệu

# %%
sales.show()
# Out:
# Materializing SFrame
# ...
# Further warnings of unsupported type will be suppressed.
# ...

# %%
turicreate.show(sales[1:5000]['sqft_living'],sales[1:5000]['price'])
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# ...

# %% [markdown]
# ## Model đơn giản dự đoán giá dựa trên diện tích

# %%
training_set, test_set = sales.random_split(.8,seed=0)

# %%
sqft_model = turicreate.linear_regression.create(training_set,target='price',features=['sqft_living'])
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# ...

# %%
print (test_set['price'].mean())
# Out:
# 543054.0425632533

# %%
print (sqft_model.evaluate(test_set))
# Out:
# {'max_error': 4139502.008735693, 'rmse': 255205.59491412912}

# %% [markdown]
# ## Khám phá model đã được train

# %%
sqft_model.coefficients
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 2
#
# Data:
# +-------------+-------+--------------------+-------------------+
# |     name    | index |       value        |       stderr      |
# +-------------+-------+--------------------+-------------------+
# | (intercept) |  None | -48359.10429126979 | 5071.025351956353 |
# | sqft_living |  None | 282.49313402988645 | 2.230046239312105 |
# +-------------+-------+--------------------+-------------------+
# [2 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(test_set['sqft_living'],test_set['price'],'.',
        test_set['sqft_living'],sqft_model.predict(test_set),'-')

# %% [markdown]
# ## Khám phá các đặc trưng dữ liệu khác

# %%
my_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors','zipcode']

# %%
sales[my_features].show()
# Out:
# Materializing SFrame
# ...

# %%
turicreate.show(sales['zipcode'],sales['price'])
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# ...

# %% [markdown]
# ## Xây dựng model dựa trên các đặc trưng đã khám phá ở trên

# %%
my_features_model = turicreate.linear_regression.create(training_set,target='price',features=my_features)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 6
# Number of unpacked features : 6
# Number of coefficients    : 75
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# ...

# %% [markdown]
# ## So sánh hai model đã train

# %%
print (my_features)
# Out:
# ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']

# %%
print (sqft_model.evaluate(test_set))
print (my_features_model.evaluate(test_set))
# Out:
# {'max_error': 4139502.008735693, 'rmse': 255205.59491412912}
# {'max_error': 3184078.8759048814, 'rmse': 180596.46805808062}

# %% [markdown]
# ## Áp dụng models vào dự đoán giá nhà

# %% [markdown]
# *// Nhà thứ 1*

# %%
house1 = sales[sales['id']=='5309101200']

# %%
house1
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+----------+----------+-----------+
# |     id     |            date           |  price   | bedrooms | bathrooms |
# +------------+---------------------------+----------+----------+-----------+
# | 5309101200 | 2014-06-05 00:00:00+00:00 | 620000.0 |   4.0    |    2.25   |
# +------------+---------------------------+----------+----------+-----------+
# +-------------+----------+--------+------------+------+-----------+-------+
# | sqft_living | sqft_lot | floors | waterfront | view | condition | grade |
# ...

# %%
print (house1['price'])
# Out:
# [620000.0, ... ]

# %%
print (sqft_model.predict(house1))
# Out:
# [629624.4173804577]

# %%
print (my_features_model.predict(house1))
# Out:
# [727337.7687444185]

# %% [markdown]
# *// Nhà thứ 2*

# %%
house2 = sales[sales['id']=='1925069082']

# %%
house2
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 1925069082 | 2015-05-11 00:00:00+00:00 | 2200000.0 |   5.0    |    4.25   |
# +------------+---------------------------+-----------+----------+-----------+
# +-------------+----------+--------+------------+------+-----------+-------+
# | sqft_living | sqft_lot | floors | waterfront | view | condition | grade |
# ...

# %%
print (sqft_model.predict(house2))
# Out:
# [1262409.0376074032]

# %%
print (my_features_model.predict(house2))
# Out:
# [1229829.999122528]

# %% [markdown]
# *// Nhà thứ 3*

# %%
bill_gates = {'bedrooms':[8], 
              'bathrooms':[25], 
              'sqft_living':[50000], 
              'sqft_lot':[225000],
              'floors':[4], 
              'zipcode':['98039'], 
              'condition':[10], 
              'grade':[10],
              'waterfront':[1],
              'view':[4],
              'sqft_above':[37500],
              'sqft_basement':[12500],
              'yr_built':[1994],
              'yr_renovated':[2010],
              'lat':[47.627606],
              'long':[-122.242054],
              'sqft_living15':[5000],
              'sqft_lot15':[40000]}

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('/content/bill_gates.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
print (my_features_model.predict(turicreate.SFrame(bill_gates)))
# Out:
# [14984948.551949184]
